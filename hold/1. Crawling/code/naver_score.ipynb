# %%
#네이버 순번 영화 관람객평점
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

ID = pd.read_csv('./kobis_tot.csv')
movie_codes = list(ID.네이버ID)
# movie_codes = [115977,121048,98438]
index = list(ID.순번)

comments = []

for movie_code, indexx in zip(movie_codes, index):
    options = webdriver.ChromeOptions()
    options.add_argument("headless")
    driver = webdriver.Chrome("./chromedriver", chrome_options=options)
    site = "https://movie.naver.com/movie/bi/mi/basic.naver?code=" + str(movie_code)
    driver.get(site)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    movie_name = soup.select("div.mv_info_area > div.mv_info > h3 > a")[0].text
    score = soup.select("#actualPointPersentBasic > div")[0].text
    a = list(score)
    aa = a[8:12]
    score = ''.join(aa)

    comments.append([indexx,movie_name,score]) 
    driver.quit()
        
df = pd.DataFrame(comments, columns=["순번","영화","관람객평점"])
print(df)
df.to_csv('./naver.csv', encoding='utf-8-sig')
# Out:
# <ipython-input-22-bcab6470de6d>:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome("./chromedriver", chrome_options=options)
# 1 베테랑
# 2 암살
# 3 어벤져스: 에이지 오브 울트론
# 4 내부자들
# 5 킹스맨 : 시크릿 에이전트
# 6 사도
# 7 미션 임파서블: 로그네이션
# 8 쥬라기 월드
# 9 연평해전
# 10 검은 사제들
# 11 마션
# 12 히말라야
# 13 인사이드 아웃
# 14 매드맥스: 분노의 도로
# 15 조선명탐정 : 사라진 놉의 딸
# 16 인턴
# 17 터미네이터 제니시스
# 18 분노의 질주: 더 세븐
# 19 스타워즈: 깨어난 포스
# 20 스물
# 21 앤트맨
# 22 극비수사
# 23 빅 히어로
# 24 메이즈 러너: 스코치 트라이얼
# 25 탐정 : 더 비기닝
# 26 미니언즈
# 27 스파이
# 28 강남 1970
# 29 악의 연대기
# 30 뷰티 인사이드
# 31 부산행
# 32 검사외전
# 33 캡틴 아메리카: 시빌 워
# 34 밀정
# 35 터널
# 36 럭키
# 37 곡성(哭聲)
# 38 인천상륙작전
# 39 닥터 스트레인지
# 40 덕혜옹주
# 41 마스터
# 42 신비한 동물사전
# 43 주토피아
# 44 아가씨
# 45 판도라
# 46 쿵푸팬더3
# 47 데드풀
# 48 귀향
# 49 나우 유 씨 미 2
# 50 엑스맨: 아포칼립스
# 51 형
# 52 미스 페레그린과 이상한 아이들의 집
# 53 정글북
# 54 제이슨 본
# 55 도리를 찾아서
# 56 아수라
# 57 라라랜드
# 58 마이펫의 이중생활
# 59 배트맨 대 슈퍼맨: 저스티스의 시작
# 60 굿바이 싱글
# 61 택시운전사
# 62 신과함께-죄와 벌
# 63 공조
# 64 스파이더맨: 홈커밍
# 65 범죄도시
# 66 군함도
# 67 청년경찰
# 68 더 킹
# ...
